# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import pandas_datareader.data as web
# Out:
# C:\Users\blueo\Anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)

# %%
df1=web.DataReader("MCD","yahoo",start="2015-02-01",end="2020-02-01")

# %%
p1=df1["Adj Close"]

# %%
df2=web.DataReader("QSR","yahoo",start="2015-02-01",end="2020-02-01")

# %%
p2=df2["Adj Close"]

# %%
df3=web.DataReader("WEN","yahoo",start="2015-02-01",end="2020-02-01")

# %%
p3=df3["Adj Close"]

# %%
p3.plot(c="red")
p2.plot(c="green")
p1.plot(c="yellow")

# %% [markdown]
# 黃:麥當勞
# 綠:漢堡王
# 紅:溫蒂漢堡
